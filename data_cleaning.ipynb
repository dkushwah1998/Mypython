# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Projects\Climate\climate-risk-index-1.csv")

# %%
df
# Out:
#      index  cartodb_id  the_geom  the_geom_webmercator              country  \
# 0        0           1       NaN                   NaN         Saudi Arabia
# 1        1           2       NaN                   NaN              Romania
# 2        2           3       NaN                   NaN                Spain
# 3        3           4       NaN                   NaN             Slovenia
# 4        4           5       NaN                   NaN          South Sudan
# ..     ...         ...       ...                   ...                  ...
# 177    177         178       NaN                   NaN           Seychelles
# 178    178         179       NaN                   NaN               Gambia
# 179    179         180       NaN                   NaN                 Togo
# 180    180         181       NaN                   NaN  Trinidad and Tobago
# 181    181         182       NaN                   NaN                Tonga
#
# ...

# %%
df.isnull().sum()
# Out:
# index                          0
# cartodb_id                     0
# the_geom                     182
# the_geom_webmercator         182
# country                        0
# cri_rank                       0
# cri_score                      0
# fatalities_per_100k_rank       0
# fatalities_per_100k_total      0
# fatalities_rank                0
# fatalities_total               0
# losses_per_gdp__rank           0
# losses_per_gdp__total         51
# losses_usdm_ppp_rank           0
# losses_usdm_ppp_total          0
# rw_country_code                3
# rw_country_name                3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      182 non-null    int64
#  1   cartodb_id                 182 non-null    int64
#  2   the_geom                   0 non-null      float64
#  3   the_geom_webmercator       0 non-null      float64
#  4   country                    182 non-null    object
#  5   cri_rank                   182 non-null    int64
#  6   cri_score                  182 non-null    float64
#  7   fatalities_per_100k_rank   182 non-null    int64
#  8   fatalities_per_100k_total  182 non-null    float64
#  9   fatalities_rank            182 non-null    int64
#  10  fatalities_total           182 non-null    int64
#  11  losses_per_gdp__rank       182 non-null    int64
#  12  losses_per_gdp__total      131 non-null    float64
# ...

# %%
df.drop(['the_geom','the_geom_webmercator'],axis = 1,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      182 non-null    int64
#  1   cartodb_id                 182 non-null    int64
#  2   country                    182 non-null    object
#  3   cri_rank                   182 non-null    int64
#  4   cri_score                  182 non-null    float64
#  5   fatalities_per_100k_rank   182 non-null    int64
#  6   fatalities_per_100k_total  182 non-null    float64
#  7   fatalities_rank            182 non-null    int64
#  8   fatalities_total           182 non-null    int64
#  9   losses_per_gdp__rank       182 non-null    int64
#  10  losses_per_gdp__total      131 non-null    float64
#  11  losses_usdm_ppp_rank       182 non-null    int64
#  12  losses_usdm_ppp_total      182 non-null    float64
# ...

# %%
mean = df['losses_per_gdp__total'].mean()

# %%
df['losses_per_gdp__total'].fillna(mean,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      182 non-null    int64
#  1   cartodb_id                 182 non-null    int64
#  2   country                    182 non-null    object
#  3   cri_rank                   182 non-null    int64
#  4   cri_score                  182 non-null    float64
#  5   fatalities_per_100k_rank   182 non-null    int64
#  6   fatalities_per_100k_total  182 non-null    float64
#  7   fatalities_rank            182 non-null    int64
#  8   fatalities_total           182 non-null    int64
#  9   losses_per_gdp__rank       182 non-null    int64
#  10  losses_per_gdp__total      182 non-null    float64
#  11  losses_usdm_ppp_rank       182 non-null    int64
#  12  losses_usdm_ppp_total      182 non-null    float64
# ...

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179 entries, 0 to 181
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      179 non-null    int64
#  1   cartodb_id                 179 non-null    int64
#  2   country                    179 non-null    object
#  3   cri_rank                   179 non-null    int64
#  4   cri_score                  179 non-null    float64
#  5   fatalities_per_100k_rank   179 non-null    int64
#  6   fatalities_per_100k_total  179 non-null    float64
#  7   fatalities_rank            179 non-null    int64
#  8   fatalities_total           179 non-null    int64
#  9   losses_per_gdp__rank       179 non-null    int64
#  10  losses_per_gdp__total      179 non-null    float64
#  11  losses_usdm_ppp_rank       179 non-null    int64
#  12  losses_usdm_ppp_total      179 non-null    float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                               index  cartodb_id  cri_rank  cri_score  \
# index                      1.000000    1.000000  0.066129   0.090049
# cartodb_id                 1.000000    1.000000  0.066129   0.090049
# cri_rank                   0.066129    0.066129  1.000000   0.992048
# cri_score                  0.090049    0.090049  0.992048   1.000000
# fatalities_per_100k_rank   0.014861    0.014861  0.833149   0.831365
# fatalities_per_100k_total  0.054163    0.054163 -0.247510  -0.252298
# fatalities_rank            0.131124    0.131124  0.796102   0.799179
# fatalities_total          -0.003455   -0.003455 -0.299780  -0.293533
# losses_per_gdp__rank       0.048963    0.048963  0.854871   0.866318
# losses_per_gdp__total      0.082771    0.082771 -0.151620  -0.154610
# losses_usdm_ppp_rank       0.185459    0.185459  0.814919   0.829412
# losses_usdm_ppp_total     -0.095569   -0.095569 -0.272639  -0.266617
#
#                            fatalities_per_100k_rank  \
# ...

# %%
df.describe()
# Out:
#             index  cartodb_id    cri_rank   cri_score  \
# count  179.000000  179.000000  179.000000  179.000000
# mean    89.368715   90.368715   85.005587   81.611508
# std     52.350035   52.350035   44.816793   34.653027
# min      0.000000    1.000000    1.000000   12.170000
# 25%     44.500000   45.500000   45.000000   52.500000
# 50%     89.000000   90.000000   91.000000   77.500000
# 75%    133.500000  134.500000  135.000000  124.500000
# max    181.000000  182.000000  135.000000  124.500000
#
#        fatalities_per_100k_rank  fatalities_per_100k_total  fatalities_rank  \
# count                179.000000                 179.000000       179.000000
# mean                  78.234637                   0.528101        77.290503
# std                   37.988625                   3.421780        37.604902
# min                    1.000000                   0.000000         1.000000
# 25%                   45.500000                   0.000000        45.500000
# ...
